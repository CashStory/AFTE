# %% [markdown]
# # Comment lire un fichier Excel?

# %%
import pandas as pd
df = pd.read_excel("EURUSD=X_TODAY.xlsx")
df
# Out:
#     Unnamed: 0       Date      Open      High       Low     Close  Adj Close  \
# 0            0 2021-10-27       NaN       NaN       NaN       NaN        NaN
# 1            1 2021-10-26       NaN       NaN       NaN       NaN        NaN
# 2            2 2021-10-25       NaN       NaN       NaN       NaN        NaN
# 3            3 2021-10-24       NaN       NaN       NaN       NaN        NaN
# 4            4 2021-10-23       NaN       NaN       NaN       NaN        NaN
# ..         ...        ...       ...       ...       ...       ...        ...
# 88          88 2021-07-05  1.185593  1.188200  1.185201  1.185621   1.185621
# 89          89 2021-07-02  1.184708  1.186099  1.181935  1.184624   1.184624
# 90          90 2021-07-01  1.185536  1.188399  1.183810  1.185677   1.185677
# 91          91 2021-06-30  1.189994  1.191043  1.184582  1.190193   1.190193
# 92          92 2021-06-29  1.193033  1.193033  1.188044  1.192890   1.192890
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0       Date  Open  High  Low  Close  Adj Close  Volume   Company  \
# 0           0 2021-10-27   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 1           1 2021-10-26   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 2           2 2021-10-25   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 3           3 2021-10-24   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 4           4 2021-10-23   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
#
#       ARIMA    LINEAR       SVR  COMPOUND
# 0  1.156203  1.179795  1.172751  1.169583
# 1  1.156203  1.179304  1.172751  1.169419
# 2  1.156203  1.178981  1.172751  1.169312
# 3  1.156203  1.179142  1.172751  1.169366
# 4  1.156203  1.179616  1.172751  1.169523

# %%
df.tail()
# Out:
#     Unnamed: 0       Date      Open      High       Low     Close  Adj Close  \
# 88          88 2021-07-05  1.185593  1.188200  1.185201  1.185621   1.185621
# 89          89 2021-07-02  1.184708  1.186099  1.181935  1.184624   1.184624
# 90          90 2021-07-01  1.185536  1.188399  1.183810  1.185677   1.185677
# 91          91 2021-06-30  1.189994  1.191043  1.184582  1.190193   1.190193
# 92          92 2021-06-29  1.193033  1.193033  1.188044  1.192890   1.192890
#
#     Volume   Company  ARIMA  LINEAR  SVR  COMPOUND
# 88     0.0  EURUSD=X    NaN     NaN  NaN       NaN
# 89     0.0  EURUSD=X    NaN     NaN  NaN       NaN
# 90     0.0  EURUSD=X    NaN     NaN  NaN       NaN
# 91     0.0  EURUSD=X    NaN     NaN  NaN       NaN
# 92     0.0  EURUSD=X    NaN     NaN  NaN       NaN

# %%
df.iloc[2:8]
# Out:
#    Unnamed: 0       Date  Open  High  Low  Close  Adj Close  Volume   Company  \
# 2           2 2021-10-25   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 3           3 2021-10-24   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 4           4 2021-10-23   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 5           5 2021-10-22   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 6           6 2021-10-21   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
# 7           7 2021-10-20   NaN   NaN  NaN    NaN        NaN     NaN  EURUSD=X
#
#       ARIMA    LINEAR       SVR  COMPOUND
# 2  1.156203  1.178981  1.172751  1.169312
# 3  1.156203  1.179142  1.172751  1.169366
# 4  1.156203  1.179616  1.172751  1.169523
# 5  1.156203  1.179224  1.172751  1.169393
# 6  1.156203  1.178001  1.172751  1.168985
# 7  1.156203  1.177850  1.172751  1.168935
